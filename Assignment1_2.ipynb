# %% [markdown]
# <a href="https://colab.research.google.com/github/AaliyanShoaib/Prediction-of-Average-Temperature-rediction-of-Average-Temperature-/blob/main/Assignment1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv('/content/annual_temp.csv')
dataset
# Out:
#       Source  Year    Mean
# 0       GCAG  2015  0.8990
# 1    GISTEMP  2015  0.8700
# 2       GCAG  2014  0.7402
# 3    GISTEMP  2014  0.7500
# 4       GCAG  2013  0.6687
# ..       ...   ...     ...
# 267  GISTEMP  1882 -0.1000
# 268     GCAG  1881 -0.0707
# 269  GISTEMP  1881 -0.1200
# 270     GCAG  1880 -0.1247
# 271  GISTEMP  1880 -0.2000
#
# [272 rows x 3 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Source  272 non-null    object
#  1   Year    272 non-null    int64
#  2   Mean    272 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.5+ KB

# %%
dataset1=dataset.iloc[::2] #Industry1
dataset2=dataset.iloc[1::2] #Industry2


x=dataset1.iloc[0:,1:-1].values #year


y1=dataset1.iloc[0:,-1:].values


y2=dataset2.iloc[0:,-1:].values
print (dataset1)
print (dataset2)
print (X)
print (y1)
print (y2)
# Out:
#     Source  Year    Mean
# 0     GCAG  2015  0.8990
# 2     GCAG  2014  0.7402
# 4     GCAG  2013  0.6687
# 6     GCAG  2012  0.6219
# 8     GCAG  2011  0.5759
# ..     ...   ...     ...
# 262   GCAG  1884 -0.2099
# 264   GCAG  1883 -0.1481
# 266   GCAG  1882 -0.0710
# 268   GCAG  1881 -0.0707
# 270   GCAG  1880 -0.1247
#
# [136 rows x 3 columns]
#       Source  Year  Mean
# 1    GISTEMP  2015  0.87
# 3    GISTEMP  2014  0.75
# 5    GISTEMP  2013  0.66
# 7    GISTEMP  2012  0.64
# 9    GISTEMP  2011  0.61
# ..       ...   ...   ...
# 263  GISTEMP  1884 -0.28
# 265  GISTEMP  1883 -0.20
# 267  GISTEMP  1882 -0.10
# 269  GISTEMP  1881 -0.12
# 271  GISTEMP  1880 -0.20
#
# [136 rows x 3 columns]
# [[2015]
#  [2014]
#  [2013]
#  [2012]
#  [2011]
#  [2010]
#  [2009]
#  [2008]
#  [2007]
#  [2006]
#  [2005]
#  [2004]
#  [2003]
#  [2002]
#  [2001]
#  [2000]
#  [1999]
#  [1998]
#  [1997]
#  [1996]
#  [1995]
#  [1994]
#  [1993]
#  [1992]
#  [1991]
#  [1990]
#  [1989]
#  [1988]
#  [1987]
# ...

# %% [markdown]
# **TRAINING** **SPLITTING** **AND** **TESTING**

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(x, y1, test_size = 0.25, random_state = 42)
X_train2, X_test2, y_train2, y_test2 = train_test_split(x, y2, test_size = 0.25, random_state = 42)

# %% [markdown]
# **LINEAR REGRESSION**

# %%
from sklearn.linear_model import LinearRegression
lte= LinearRegression()
lte.fit(X_train1,y_train1)
lte2.fit(X_train2,y_train2)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train1,y_train1,color = 'red')
plt.plot(X_train1,lte.predict(X_train1),color = 'blue')
plt.title(' Linear Regression For 1')
plt.xlabel('Years')
plt.ylabel('Mean Temp')
plt.show()
print("Accuracy: ",lte.score(X_test1,y_test1)* 100)
# Out:
# Accuracy:  73.8165960710989

# %%
plt.scatter(X_train2,y_train2,color = 'red')
plt.plot(X_train2,lte.predict(X_train2),color = 'blue')
plt.title(' Linear Regression For 2')
plt.xlabel('Years')
plt.ylabel('Mean Temp')
plt.show()
print("Accuracy: ",lte.score(X_test2,y_test2)* 100)
# Out:
# Accuracy:  75.19966365274368

# %%
print ('2016 Prediction for 1  : ' , lte.predict([[2016]]))
print ('2017 Prediction for 1  : ' , lte.predict([[2017]]))
print ('2016 Prediction for 2  : ' , lte2.predict([[2016]]))
print ('2017 Prediction for 2  : ' , lte2.predict([[2017]]))
# Out:
# 2016 Prediction for 1  :  [[0.51225802]]
# 2017 Prediction for 1  :  [[0.51908826]]
# 2016 Prediction for 2  :  [[0.50462134]]
# 2017 Prediction for 2  :  [[0.51168027]]

# %% [markdown]
# **POLYNOMIAL REGRESSION**

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_fit=PolynomialFeatures(degree=90)
k=poly_fit.fit_transform(X_train1)
k_test=poly_fit.transform(X_test1)
lte2=LinearRegression()
lte2.fit(k,y_train1)
ypred= lte2.predict(k)
ypredtest= lte2.predict(k_test)

poly_fit2=PolynomialFeatures(degree=90)
k2=poly_fit.fit_transform(X_train2)
k_test2=poly_fit.transform(X_test2)
lte3=LinearRegression()
lte3.fit(k2,y_train2)
ypred2= lte2.predict(k2)
ypredtest2= lte2.predict(k_test2)
# Out:
# LinearRegression()

# %%
x_grid=np.arange(min(X_train1),max(X_train1),0.01)
x_grid=x_grid.reshape((len(x_grid),1))
x_grid_poly = poly_fit.transform(x_grid)
plt.scatter(X_train1,y_train1,color = 'red')
plt.plot(x_grid,lte2.predict(x_grid_poly),color='blue')
train_score = lte2.score(k,y_train1)
test_score = lte2.score(k_test,y_test1)
print("Training Accuracy  ", train_score * 100)
# Out:
# Training Accuracy   86.10346467777794
# <ipython-input-24-14f8b2c85203>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(X_train1),max(X_train1),0.01)

# %%
x_grid2=np.arange(min(X_train2),max(X_train2),0.01)
x_grid2=x_grid2.reshape((len(x_grid2),1))
x_grid_poly2 = poly_fit.transform(x_grid2)
plt.scatter(X_train2,y_train2,color = 'red')
plt.plot(x_grid,lte2.predict(x_grid_poly2),color='blue')
train_score2 = lte2.score(k2,y_train2)
test_score2 = lte2.score(k_test2,y_test2)
print("Training Accuracy  ", train_score2 * 100)
# Out:
# Training Accuracy   86.37119185363751
# <ipython-input-43-cb0109e0cdf9>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid2=np.arange(min(X_train2),max(X_train2),0.01)

# %%
print ('2016 Prediction for 1  : ' , lte2.predict(poly_fit.fit_transform([[2016]])))
print ('2017 Prediction  for 1 : ' , lte2.predict(poly_fit.fit_transform([[2017]])))
print ('2016 Prediction for 1  : ' , lte3.predict(poly_fit2.fit_transform([[2016]])))
print ('2017 Prediction  for 1 : ' , lte3.predict(poly_fit2.fit_transform([[2017]])))
# Out:
# 2016 Prediction for 1  :  [[0.82100093]]
# 2017 Prediction  for 1 :  [[0.84999936]]
# 2016 Prediction for 1  :  [[0.81892022]]
# 2017 Prediction  for 1 :  [[0.8444424]]

# %% [markdown]
# **DECISION TREE REGRESSION**

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=42)
dtr2 = DecisionTreeRegressor(random_state=42)
dtr.fit(X_train1,y_train1)
dtr2.fit(X_train2,y_train2)
train3_score = dtr.score(X_train1,y_train1)
test3_score = dtr.score(X_test1,y_test1)
train4_score = dtr2.score(X_train2,y_train2)
test4_score = dtr2.score(X_test2,y_test2)

# %%
x_grid3=np.arange(min(X_train1),max(X_train1),0.01)
x_grid3=x_grid3.reshape((len(x_grid3),1))
plt.scatter(X_train1,y_train1,color='red')
plt.plot(x_grid3,dtr.predict(x_grid3),color='blue')
plt.show()
print(" Accuracy  ", test3_score* 100)
# Out:
# <ipython-input-29-1949cd110475>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid3=np.arange(min(X_train1),max(X_train1),0.01)
# Training Accuracy   86.76590228261398

# %%
x_grid4=np.arange(min(X_train2),max(X_train2),0.01)
x_grid4=x_grid4.reshape((len(x_grid4),1))
plt.scatter(X_train2,y_train2,color='red')
plt.plot(x_grid4,dtr.predict(x_grid4),color='blue')
plt.show()
print(" Accuracy  ", test4_score* 100)
# Out:
# <ipython-input-30-8d1b96beba43>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid4=np.arange(min(X_train2),max(X_train2),0.01)
# Training Accuracy   86.93544354707218

# %%
print ('2016 Prediction for 1  : ' , dtr.predict([[2016]]))
print ('2017 Prediction  for 1 : ' , dtr.predict([[2017]]))

print ('2016 Prediction for 2  : ' , dtr2.predict([[2016]]))
print ('2017 Prediction  for 2 : ' , dtr2.predict([[2017]]))
# Out:
# 2016 Prediction for 1  :  [0.899]
# 2017 Prediction  for 1 :  [0.899]
# 2016 Prediction for 2  :  [0.87]
# 2017 Prediction  for 2 :  [0.87]

# %% [markdown]
# **RANDOM FOREST REGRESSION**

# %%
from sklearn.ensemble import RandomForestRegressor
regressor1 = RandomForestRegressor(n_estimators = 140 , random_state= 1)
regressor2 = RandomForestRegressor(n_estimators = 140 , random_state= 1)
regressor1.fit(X_train1, y_train1)
regressor2.fit(X_train2, y_train2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=140, random_state=1)

# %%
x_grid5=np.arange(min(X_train1),max(X_train1),0.01)
x_grid5=x_grid5.reshape((len(x_grid5),1))
plt.scatter(X_train1,y_train1,color='red')
plt.plot(x_grid5,regressor2.predict(x_grid5),color='blue')
plt.show()
tscore = regressor1.score(X_test1,y_test1)
print(" Accuracy  ", tscore * 100)
# Out:
# <ipython-input-34-77eaf2a76f99>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid5=np.arange(min(X_train1),max(X_train1),0.01)
#  Accuracy   89.74955953887141

# %%
x_grid6=np.arange(min(X_train2),max(X_train2),0.01)
x_grid6=x_grid6.reshape((len(x_grid6),1))
plt.scatter(X_train2,y_train2,color='red')
plt.plot(x_grid6,regressor2.predict(x_grid6),color='blue')
plt.show()
tscore2 = regressor2.score(X_test2,y_test2)
print("Accuracy  ", tscore2 * 100)
# Out:
# <ipython-input-37-5bb205172162>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid6=np.arange(min(X_train2),max(X_train2),0.01)
# Accuracy   90.0645441318369

# %%
print ('2016 Prediction for 1  : ' , regressor1.predict([[2016]]))
print ('2017 Prediction  for 1 : ' , regressor1.predict([[2017]]))

print ('2016 Prediction for 2  : ' , regressor2.predict([[2016]]))
print ('2017 Prediction  for 2 : ' , regressor2.predict([[2017]]))
# Out:
# 2016 Prediction for 1  :  [0.81963143]
# 2017 Prediction  for 1 :  [0.81963143]
# 2016 Prediction for 2  :  [0.80407143]
# 2017 Prediction  for 2 :  [0.80407143]

# %% [markdown]
# **CONCLUSION**
#
# After performing all the regressions, it is observed that Random Forest Regression gives the best results compared to others.
